# %%
# ライブラリの読み込み
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ファイルの読み込み込み
performance = pd.read_csv('../Data/team_performance.csv')
sales = pd.read_csv('../Data/team_merch_sales.csv')

# %%
# チームごとのすべての売り上げを合計する
annual_sales = sales.groupby('TeamID', as_index=False)['MerchRevenueJPY'].sum()

# %%
# 2つのファイルを合わせる
merged = pd.merge(performance, annual_sales, on='TeamID')

# %%
# データの可視化
plt.scatter(merged['WinRate'], merged['MerchRevenueJPY'])

# %%
plt.xlabel('WinRate')
plt.ylabel('Sales')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 今日の学び
#
# ## 学んだ内容
# - `plt.scatter()`で散布図を作れるようになった。
#   → データの傾向や相関を視覚的に確認する方法を理解した。
# - `merge`(`concat`)関数でチーム成績データと売上データを結合し、1つのデータフレームにまとめた。
#   → 異なるデータソースを組み合わせて新しい指標を作る方法を学んだ。
#
# ## 所感
# - 今回のデータでは、勝率とグッズ売上の間に明確な相関は見られなかった。今回のデータではサンプル数が少なく、相関の有無を判断するには十分ではないと感じた。
# - 今回学んだ「データ結合」や「可視化」を基礎にして、今後は実データに近い複雑なデータセットを扱う練習を積んでいきたい。
