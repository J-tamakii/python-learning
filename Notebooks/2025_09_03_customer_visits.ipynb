# %%
# ライブラリの読み込みと共通設定
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

bins = range(0, 16)

# %%
# ファイルの読み込み込み
customer_visits = pd.read_csv('../Data/customer_visits (1).csv')

# %%
# 男性の来店回数の可視化
plt.subplot(1, 2, 1)
df_male = customer_visits.query('Gender == "Male"')
plt.hist(df_male['Visits'])
plt.title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# 女性の来店回数の可視化
plt.subplot(1, 2, 2)
df_female = customer_visits.query('Gender == "Female"')
plt.hist(df_female['Visits'])
plt.title('Female')
# Out:
# Text(0.5, 1.0, 'Female')

# %%
plt.figure(figsize = (15, 5))
plt.tight_layout()
plt.show()

# %%
# 属性に'年代'を追加
customer_visits['AgeGroup'] = np.floor(customer_visits['Age'] / 10) * 10

# %%
# 10代の来店回数の可視化
plt.subplot(2, 3, 1)
under_20years = customer_visits.query('AgeGroup == 10')
plt.hist(under_20years['Visits'], bins = bins)
plt.title('10s')
plt.xlabel('Number of Visits')
plt.ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
# 20代の来店回数の可視化
plt.subplot(2, 3, 2)
over_20years = customer_visits.query('AgeGroup == 20')
plt.hist(over_20years['Visits'], bins = bins)
plt.title('20s')
plt.xlabel('Number of Visits')
plt.ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
# 30代の来店回数の可視化
plt.subplot(2, 3, 3)
over_30years = customer_visits.query('AgeGroup == 30')
plt.hist(over_30years['Visits'], bins = bins)
plt.title('30s')
plt.xlabel('Number of Visits')
plt.ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
# 40代の来店回数の可視化
plt.subplot(2, 3, 4)
over_40years = customer_visits.query('AgeGroup == 40')
plt.hist(over_40years['Visits'], bins = bins)
plt.title('40s')
plt.xlabel('Number of Visits')
plt.ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
# 50代の来店回数の可視化
plt.subplot(2, 3, 5)
over_50years = customer_visits.query('AgeGroup == 50')
plt.hist(over_50years['Visits'], bins = bins)
plt.title('50s')
plt.xlabel('Number of Visits')
plt.ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
# 60代の来店回数の可視化
plt.subplot(2, 3, 6)
over_60years = customer_visits.query('AgeGroup == 60')
plt.hist(over_60years['Visits'], bins = bins)
plt.title('60s')
plt.xlabel('Number of Visits')
plt.ylabel('Number of Customers')
# Out:
# Text(0, 0.5, 'Number of Customers')

# %%
plt.figure(figsize = (15, 5))
plt.tight_layout()
plt.show()

# %% [markdown]
# # 今日の学び
#
# ## 学んだ内容
# - `query` 関数を使って、条件に合う行を抽出し、属性ごとのグラフを作成できるようになった。
# - ヒストグラムを用いて、値の分布を可視化する方法を理解した。
# - サブプロットを使って、1つの図に複数のグラフを表示する方法を学んだ。
#
# ## 少し躓いた点
# - scriptでファイルを読み取る際にnotebookで用いているやり方ではエラーが出てしまった。
# - 作業ディレクトリが異なるそうで、script実行時はプロジェクト直下を基準に `Data/customer_visits (1).csv` と指定することで解決した。
#
# ## 所感
# - 本日の演習では、属性ごとにデータを抽出して可視化する一連の流れを体験できた。
# - 特に `query` 関数を使った行抽出は直感的で分かりやすく、実務でも頻繁に使うのではないかと感じた。
# - また、ヒストグラムを用いることでデータの分布が一目で分かり、分析の第一歩として有効だと感じた。
# - さらに、サブプロットを使って複数のグラフを1つにまとめることで、グループごとの傾向を比較しやすくなる点も学んだ。
# - その際、グラフのラベル同士が重なることがあったが、`plt.tight_layout()`と指定することできれいな余白ができ感動した。
# - 今後は、より複雑な条件でのデータ抽出や、可視化の見せ方の工夫にも取り組んでいきたい。
